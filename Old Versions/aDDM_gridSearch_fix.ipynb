# %% [raw]
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %% [markdown]
# # aDDM_gridSearch Script

# %% [markdown]
# Implement the iterative step for the search of optimal parameter sets. Use of aDDM_pta_mla script from addm_toolbox (https://github.com/goptavares/aDDM-Toolbox)

# %%
from __future__ import absolute_import
import argparse
from addm_toolbox import addm_pta_mle_limited
import numpy as np
import pandas as pd

# %%
import addm_toolbox

# %%
addm_toolbox
# Out:
# <module 'addm_toolbox' from '/Users/pradyumna/anaconda/lib/python3.5/site-packages/addm_toolbox/__init__.py'>

# %% [markdown]
# ### + Free parameters in the model
#
# #####    d : controls speed of signal integration (Free DDM parameter)
# #####   sigma: standard deviation of normal distribution (Free DDM parameter)
# #####   theta: controls attentional bias (Free aDDM parameter)
#
# ### + Inputs for toolobox addm_pta_mle script
# ##### range_d,range_sigma,range_theta : range to define the grid for parameter search
# ##### trials_file_name : filepath with trial conditions (to be used for simulations)
# ##### expdata_file_name :  filepath with trial info [participant, trial number, RT, response, values]
# ##### fixations_file_name : filepath with fixations info [participant, trial num, fixation_id, fixation_time]
# ##### Extra parameters: trials_per_subject, simulations_per_condition, subject_ids (number of the subjects to be included for adjusting the parameters, num_threads (parallel processing),save_simulations, save_figures, verbose (deliver reports)
#
# ###  + Initial grid selection:
# ##### range_d = [0.003, 0.006, 0.009] ; range_sigma = [0.03, 0.06, 0.09] ; range_theta = [0.3, 0.5, 0.7]
#
# ### + Iteration (adjustment to a new grid) until the change in min NNL is <1%

# %% [markdown]
# ## Dislike condition grid iterations

# %%
iteration_data = []
current_min_nll = 0
previous_min_nll = 0


# Initial grid selection
range_d = [0.003, 0.006, 0.009]
range_sigma = [0.03, 0.06, 0.09]
range_theta = [0.3, 0.5, 0.7]

#data files definition
trials_file_name = None
expdata_file_name = '/Users/bdmlab/OneDrive - University College London/PhD Projects/GiTs/FF2018/InputData/expdata_FFA_Dislike_v2.csv'
fixations_file_name = '/Users/bdmlab/OneDrive - University College London/PhD Projects/GiTs/FF2018/InputData/fixations_FFA_Dislike_v2.csv'
trials_per_subject = 120
simulations_per_condition = 300

iter_num = 1

while (abs(current_min_nll-previous_min_nll) > (previous_min_nll*1/100)) or iter_num == 1:
    
    if iter_num > 1:  
        delta_d = range_d[1]-range_d[0]
        delta_sigma = range_sigma[1] - range_sigma[0]
        delta_theta = range_theta[1] - range_theta[0]
        
        range_d = [new_d - delta_d/2 , new_d ,new_d + delta_d/2]
        range_sigma =[new_sigma - delta_sigma/2 , new_sigma ,new_sigma + delta_sigma/2]
        range_theta =[new_theta - delta_theta/2 , new_theta ,new_theta + delta_theta/2]
    
    
    #run the toolbox
    a = addm_pta_mle_limited.main(range_d, range_sigma, range_theta,
                      None, 
                      expdata_file_name,
                      fixations_file_name, 
                      trials_per_subject,simulations_per_condition, [],
                      9, True, True,
                      True)
    
    # Update the NLL values for this iteration
    previous_min_nll = current_min_nll
    current_min_nll = a[1]
    
    #get the new values
    new_d = a[0][0]
    new_sigma = a[0][1]
    new_theta = a[0][2]
    
    iteration_data.append([iter_num,new_d, new_sigma, new_theta,current_min_nll]) 

    iter_num = iter_num + 1



    
    
iteration_dataf=pd.DataFrame(iteration_data,columns=['Iteration', 'd', 'sigma', 'theta', 'min_NLL'])
print ("Finished iterations!!")

# %%
iterations_dislike = iteration_dataf
iterations_dislike

# %% [markdown]
# ## Like condition grid iterations

# %%
iteration_data = []
current_min_nll = 0
previous_min_nll = 0


# Initial grid selection
range_d = [0.003, 0.006, 0.009]
range_sigma = [0.03, 0.06, 0.09]
range_theta = [0.3, 0.5, 0.7]

#data files definition
trials_file_name = None
expdata_file_name = '/Users/bdmlab/OneDrive - University College London/PhD Projects/GiTs/FF2018/InputData/expdata_FFA_Like_v2.csv'
fixations_file_name = '/Users/bdmlab/OneDrive - University College London/PhD Projects/GiTs/FF2018/InputData/fixations_FFA_Like_v2.csv'
trials_per_subject = 120
simulations_per_condition = 300

iter_num = 1

while (abs(current_min_nll-previous_min_nll) > (previous_min_nll*1/100)) or iter_num == 1:
    
    if iter_num > 1:
        delta_d = range_d[1]-range_d[0]
        delta_sigma = range_sigma[1] - range_sigma[0]
        delta_theta = range_theta[1] - range_theta[0]
        
        range_d = [new_d - delta_d/2 , new_d ,new_d + delta_d/2]
        range_sigma =[new_sigma - delta_sigma/2 , new_sigma ,new_sigma + delta_sigma/2]
        range_theta =[new_theta - delta_theta/2 , new_theta ,new_theta + delta_theta/2]
    
    
    #run the toolbox
    a = addm_pta_mle_limited.main(range_d, range_sigma, range_theta,
                      None, 
                      expdata_file_name,
                      fixations_file_name, 
                      trials_per_subject,simulations_per_condition, [],
                      9, True, True,
                      True)
    
    # Update the NLL values for this iteration
    previous_min_nll = current_min_nll
    current_min_nll = a[1]
    
    #get the new values
    new_d = a[0][0]
    new_sigma = a[0][1]
    new_theta = a[0][2]
    
    iteration_data.append([iter_num,new_d, new_sigma, new_theta,current_min_nll]) 

    iter_num = iter_num + 1



    
    
iteration_dataf=pd.DataFrame(iteration_data,columns=['Iteration', 'd', 'sigma', 'theta', 'min_NLL'])
print ("Finished iterations!!")

# %%
iterations_like = iteration_dataf
iterations_like

# %% [markdown]
# # traditional DDM run
#
# ### According to Tavares et al (2017) traditional DDM model is obtained when the attentional parameter (theta) is fixed to 1

# %%
from addm_toolbox import ddm_pta_test

# %% [markdown]
# ## Like condition

# %%
iteration_data = []
current_min_nll = 0
previous_min_nll = 0


# Initial grid selection
range_d = [0.003, 0.006, 0.009]
range_sigma = [0.03, 0.06, 0.09]
range_theta = [1]

#data files definition
trials_file_name = None
expdata_file_name = '/Users/bdmlab/OneDrive - University College London/PhD Projects/GiTs/FF2018/InputData/expdata_FFA_Like_v2.csv'
fixations_file_name = '/Users/bdmlab/OneDrive - University College London/PhD Projects/GiTs/FF2018/InputData/fixations_FFA_Like_v2.csv'
trials_per_subject = 120
simulations_per_condition = 300

iter_num = 1

while (abs(current_min_nll-previous_min_nll) > (previous_min_nll*1/100)) or iter_num == 1:
    
    if iter_num > 1:
        delta_d = range_d[1]-range_d[0]
        delta_sigma = range_sigma[1] - range_sigma[0]
       # delta_theta = range_theta[1] - range_theta[0]
        
        range_d = [new_d - delta_d/2 , new_d ,new_d + delta_d/2]
        range_sigma =[new_sigma - delta_sigma/2 , new_sigma ,new_sigma + delta_sigma/2]
       # range_theta =[new_theta - delta_theta/2 , new_theta ,new_theta + delta_theta/2]
    
    
    #run the toolbox
    a = addm_pta_mle_limited.main(range_d, range_sigma, range_theta,
                      None, 
                      expdata_file_name,
                      fixations_file_name, 
                      trials_per_subject,simulations_per_condition, [],
                      9, True, True,
                      True)
    
    # Update the NLL values for this iteration
    previous_min_nll = current_min_nll
    current_min_nll = a[1]
    
    #get the new values
    new_d = a[0][0]
    new_sigma = a[0][1]
    new_theta = a[0][2]
    
    iteration_data.append([iter_num,new_d, new_sigma, new_theta,current_min_nll]) 

    iter_num = iter_num + 1



    
    
iteration_dataf=pd.DataFrame(iteration_data,columns=['Iteration', 'd', 'sigma', 'theta', 'min_NLL'])
print ("Finished iterations!!")

# %% [markdown]
# ## Dislike condition

# %%
iteration_data = []
current_min_nll = 0
previous_min_nll = 0


# Initial grid selection
range_d = [0.003, 0.006, 0.009]
range_sigma = [0.03, 0.06, 0.09]
range_theta = [1]

#data files definition
trials_file_name = None
expdata_file_name = '/Users/bdmlab/OneDrive - University College London/PhD Projects/GiTs/FF2018/InputData/expdata_FFA_Dislike_v2.csv'
fixations_file_name = '/Users/bdmlab/OneDrive - University College London/PhD Projects/GiTs/FF2018/InputData/fixations_FFA_Dislike_v2.csv'
trials_per_subject = 120
simulations_per_condition = 300

iter_num = 1

while (abs(current_min_nll-previous_min_nll) > (previous_min_nll*1/100)) or iter_num == 1:
    
    if iter_num > 1:
        delta_d = range_d[1]-range_d[0]
        delta_sigma = range_sigma[1] - range_sigma[0]
       # delta_theta = range_theta[1] - range_theta[0]
        
        range_d = [new_d - delta_d/2 , new_d ,new_d + delta_d/2]
        range_sigma =[new_sigma - delta_sigma/2 , new_sigma ,new_sigma + delta_sigma/2]
       # range_theta =[new_theta - delta_theta/2 , new_theta ,new_theta + delta_theta/2]
    
    
    #run the toolbox
    a = addm_pta_mle_limited.main(range_d, range_sigma, range_theta,
                      None, 
                      expdata_file_name,
                      fixations_file_name, 
                      trials_per_subject,simulations_per_condition, [],
                      9, True, True,
                      True)
    
    # Update the NLL values for this iteration
    previous_min_nll = current_min_nll
    current_min_nll = a[1]
    
    #get the new values
    new_d = a[0][0]
    new_sigma = a[0][1]
    new_theta = a[0][2]
    
    iteration_data.append([iter_num,new_d, new_sigma, new_theta,current_min_nll]) 

    iter_num = iter_num + 1
   
iteration_dataf=pd.DataFrame(iteration_data,columns=['Iteration', 'd', 'sigma', 'theta', 'min_NLL'])
print ("Finished iterations!!")

# %% [markdown]
# ***
#
# # DDM model using HDDM
#
# ### Additionally, HDDM (http://ski.clps.brown.edu/hddm_docs/) was used to calculate the parameters. In this case the parameters are defined in a different way than in Tavares's toolbox.
#
# The speed with which the accumulation process approaches one of the two boundaries is called drift-rate __v__ and represents the relative evidence for or against a particular response.
#
# The distance between the two boundaries (i.e. threshold **a** ) influences how much evidence must be accumulated until a response is executed.
#
# Response time, however, is not solely comprised of the decision making process – perception, movement initiation and execution all take time and are lumped in the DDM by a single non-decision time parameter __t__.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import hddm

# %% [markdown]
# ## Like condition

# %%
data = hddm.load_csv('/Users/bdmlab/OneDrive - University College London/PhD Projects/GiTs/FF2018/InputData/DDM_HDDM_input/expdata_FFA_Like_DDM_v1.csv')

# %%
# Instantiate model object passing it our data (no need to call flip_errors() before passing it).
# This will tailor an individual hierarchical DDM around your dataset.
m = hddm.HDDM(data)

# %%
# find a good starting point which helps with the convergence.
m.find_starting_values()

# %%
# start drawing 7000 samples and discarding 5000 as burn-in
m.sample(2000, burn=20)

# %%
# Print fitted parameters and other model statistics
m.print_stats()

# Plot posterior distributions and theoretical RT distributions
m.plot_posteriors()
m.plot_posterior_predictive()

# %% [markdown]
# ## Dislike condition

# %%
data = hddm.load_csv('/Users/bdmlab/OneDrive - University College London/PhD Projects/GiTs/FF2018/InputData/DDM_HDDM_input/expdata_FFA_Dislike_DDM_v1.csv')

# %%
# Instantiate model object passing it our data (no need to call flip_errors() before passing it).
# This will tailor an individual hierarchical DDM around your dataset.
m = hddm.HDDM(data)

# find a good starting point which helps with the convergence.
m.find_starting_values()

# start drawing 7000 samples and discarding 5000 as burn-in
m.sample(2000, burn=20)

# %%
# Print fitted parameters and other model statistics
m.print_stats()

# Plot posterior distributions and theoretical RT distributions
m.plot_posteriors()
m.plot_posterior_predictive()

# %% [markdown]
# ***

# %%
from __future__ import absolute_import
import argparse
from addm_toolbox import addm_pta_mle_limited
import numpy as np
import pandas as pd
import addm_toolbox

# %% [markdown]
# ### Recalculation of aDDM grid iterations using version of the script that does not transform item values
# ## Dislike condition

# %%
iteration_data = []
current_min_nll = 0
previous_min_nll = 0


# Initial grid selection
range_d = [0.003, 0.006, 0.009]
range_sigma = [0.03, 0.06, 0.09]
range_theta = [0.3, 0.5, 0.7]

#data files definition
trials_file_name = None
#expdata_file_name = '/Users/bdmlab/OneDrive - University College London/PhD Projects/GiTs/FF2018/InputData/expdata_FFA_Dislike_v2.csv'
#fixations_file_name = '/Users/bdmlab/OneDrive - University College London/PhD Projects/GiTs/FF2018/InputData/fixations_FFA_Dislike_v2.csv'
expdata_file_name = '/Users/pradyumna/Documents/gitDocs/FF2018/InputData/expdata_FFA_Dislike_v2.csv'
fixations_file_name = '/Users/pradyumna/Documents/gitDocs/FF2018/InputData/fixations_FFA_Dislike_v2.csv'

trials_per_subject = 120
simulations_per_condition = 300

iter_num = 1

while [(abs(current_min_nll-previous_min_nll) > (previous_min_nll*1/100)) and ((current_min_nll-previous_min_nll)>0) ]  or iter_num == 1:
    
    if iter_num > 1:  
        delta_d = range_d[1]-range_d[0]
        delta_sigma = range_sigma[1] - range_sigma[0]
        delta_theta = range_theta[1] - range_theta[0]
        
        range_d = [new_d - delta_d/2 , new_d ,new_d + delta_d/2]
        range_sigma =[new_sigma - delta_sigma/2 , new_sigma ,new_sigma + delta_sigma/2]
        range_theta =[new_theta - delta_theta/2 , new_theta ,new_theta + delta_theta/2]
    
    
    #run the toolbox
    a = addm_pta_mle_limited.main(range_d, range_sigma, range_theta,
                      None, 
                      expdata_file_name,
                      fixations_file_name, 
                      trials_per_subject,simulations_per_condition, [],
                      9, True, True,
                      True)
    
    # Update the NLL values for this iteration
    previous_min_nll = current_min_nll
    current_min_nll = a[1]
    
    #get the new values
    new_d = a[0][0]
    new_sigma = a[0][1]
    new_theta = a[0][2]
    
    iteration_data.append([iter_num,new_d, new_sigma, new_theta,current_min_nll]) 

    iter_num = iter_num + 1



    
    
iteration_dataf=pd.DataFrame(iteration_data,columns=['Iteration', 'd', 'sigma', 'theta', 'min_NLL'])
print ("Finished iterations!!")
# Out:
# Loading experimental data...
# No convert values
# Starting grid search...
# Computing likelihoods for model (0.003, 0.03, 0.3)...
# Computing likelihoods for model (0.003, 0.03, 0.5)...
# Computing likelihoods for model (0.003, 0.03, 0.7)...
# Computing likelihoods for model (0.003, 0.06, 0.3)...
# Computing likelihoods for model (0.003, 0.06, 0.5)...
# Computing likelihoods for model (0.003, 0.06, 0.7)...
# Computing likelihoods for model (0.003, 0.09, 0.3)...
# Computing likelihoods for model (0.003, 0.09, 0.5)...
# Computing likelihoods for model (0.003, 0.09, 0.7)...
# Computing likelihoods for model (0.006, 0.03, 0.3)...
# Computing likelihoods for model (0.006, 0.03, 0.5)...
# Computing likelihoods for model (0.006, 0.03, 0.7)...
# Computing likelihoods for model (0.006, 0.06, 0.3)...
# Computing likelihoods for model (0.006, 0.06, 0.5)...
# Computing likelihoods for model (0.006, 0.06, 0.7)...
# Computing likelihoods for model (0.006, 0.09, 0.3)...
# Computing likelihoods for model (0.006, 0.09, 0.5)...
# Computing likelihoods for model (0.006, 0.09, 0.7)...
# Computing likelihoods for model (0.009, 0.03, 0.3)...
# Computing likelihoods for model (0.009, 0.03, 0.5)...
# Computing likelihoods for model (0.009, 0.03, 0.7)...
# Computing likelihoods for model (0.009, 0.06, 0.3)...
# Computing likelihoods for model (0.009, 0.06, 0.5)...
# Computing likelihoods for model (0.009, 0.06, 0.7)...
# Computing likelihoods for model (0.009, 0.09, 0.3)...
# Computing likelihoods for model (0.009, 0.09, 0.5)...
# Computing likelihoods for model (0.009, 0.09, 0.7)...
# Finished grid search!
# Optimal d: 0.003
# Optimal sigma: 0.06
# Optimal theta: 0.3
# Min NLL: 14426.3208307
# PS modification to avoid calculating simulations. To undo, please uncomment last section at /Users/bdmlab/anaconda3/lib/python3.6/site-packages/addm_toolbox/addm_pta_mle.py
# Loading experimental data...
# No convert values
# Starting grid search...
# Computing likelihoods for model (0.0015, 0.045, 0.19999999999999998)...
# Computing likelihoods for model (0.0015, 0.045, 0.3)...
# Computing likelihoods for model (0.0015, 0.045, 0.4)...
# Computing likelihoods for model (0.0015, 0.06, 0.19999999999999998)...
# Computing likelihoods for model (0.0015, 0.06, 0.3)...
# Computing likelihoods for model (0.0015, 0.06, 0.4)...
# Computing likelihoods for model (0.0015, 0.075, 0.19999999999999998)...
# Computing likelihoods for model (0.0015, 0.075, 0.3)...
# Computing likelihoods for model (0.0015, 0.075, 0.4)...
# Computing likelihoods for model (0.003, 0.045, 0.19999999999999998)...
# Computing likelihoods for model (0.003, 0.045, 0.3)...
# Computing likelihoods for model (0.003, 0.045, 0.4)...
# Computing likelihoods for model (0.003, 0.06, 0.19999999999999998)...
# Computing likelihoods for model (0.003, 0.06, 0.3)...
# Computing likelihoods for model (0.003, 0.06, 0.4)...
# Computing likelihoods for model (0.003, 0.075, 0.19999999999999998)...
# Computing likelihoods for model (0.003, 0.075, 0.3)...
# Computing likelihoods for model (0.003, 0.075, 0.4)...
# Computing likelihoods for model (0.0045000000000000005, 0.045, 0.19999999999999998)...
# Computing likelihoods for model (0.0045000000000000005, 0.045, 0.3)...
# Computing likelihoods for model (0.0045000000000000005, 0.045, 0.4)...
# Computing likelihoods for model (0.0045000000000000005, 0.06, 0.19999999999999998)...
# Computing likelihoods for model (0.0045000000000000005, 0.06, 0.3)...
# Computing likelihoods for model (0.0045000000000000005, 0.06, 0.4)...
# Computing likelihoods for model (0.0045000000000000005, 0.075, 0.19999999999999998)...
# Computing likelihoods for model (0.0045000000000000005, 0.075, 0.3)...
# Computing likelihoods for model (0.0045000000000000005, 0.075, 0.4)...
# Finished grid search!
# Optimal d: 0.0015
# Optimal sigma: 0.06
# Optimal theta: 0.19999999999999998
# Min NLL: 14249.165216
# PS modification to avoid calculating simulations. To undo, please uncomment last section at /Users/bdmlab/anaconda3/lib/python3.6/site-packages/addm_toolbox/addm_pta_mle.py
# Loading experimental data...
# No convert values
# Starting grid search...
# Computing likelihoods for model (0.00075, 0.0525, 0.14999999999999997)...
# Computing likelihoods for model (0.00075, 0.0525, 0.19999999999999998)...
# Computing likelihoods for model (0.00075, 0.0525, 0.25)...
# Computing likelihoods for model (0.00075, 0.06, 0.14999999999999997)...
# Computing likelihoods for model (0.00075, 0.06, 0.19999999999999998)...
# Computing likelihoods for model (0.00075, 0.06, 0.25)...
# Computing likelihoods for model (0.00075, 0.0675, 0.14999999999999997)...
# Computing likelihoods for model (0.00075, 0.0675, 0.19999999999999998)...
# Computing likelihoods for model (0.00075, 0.0675, 0.25)...
# Computing likelihoods for model (0.0015, 0.0525, 0.14999999999999997)...
# Computing likelihoods for model (0.0015, 0.0525, 0.19999999999999998)...
# Computing likelihoods for model (0.0015, 0.0525, 0.25)...
# Computing likelihoods for model (0.0015, 0.06, 0.14999999999999997)...
# Computing likelihoods for model (0.0015, 0.06, 0.19999999999999998)...
# Computing likelihoods for model (0.0015, 0.06, 0.25)...
# Computing likelihoods for model (0.0015, 0.0675, 0.14999999999999997)...
# Computing likelihoods for model (0.0015, 0.0675, 0.19999999999999998)...
# Computing likelihoods for model (0.0015, 0.0675, 0.25)...
# Computing likelihoods for model (0.0022500000000000003, 0.0525, 0.14999999999999997)...
# Computing likelihoods for model (0.0022500000000000003, 0.0525, 0.19999999999999998)...
# Computing likelihoods for model (0.0022500000000000003, 0.0525, 0.25)...
# Computing likelihoods for model (0.0022500000000000003, 0.06, 0.14999999999999997)...
# Computing likelihoods for model (0.0022500000000000003, 0.06, 0.19999999999999998)...
# Computing likelihoods for model (0.0022500000000000003, 0.06, 0.25)...
# Computing likelihoods for model (0.0022500000000000003, 0.0675, 0.14999999999999997)...
# Computing likelihoods for model (0.0022500000000000003, 0.0675, 0.19999999999999998)...
# Computing likelihoods for model (0.0022500000000000003, 0.0675, 0.25)...
# Finished grid search!
# Optimal d: 0.0015
# Optimal sigma: 0.0525
# Optimal theta: 0.14999999999999997
# Min NLL: 14100.5601786
# PS modification to avoid calculating simulations. To undo, please uncomment last section at /Users/bdmlab/anaconda3/lib/python3.6/site-packages/addm_toolbox/addm_pta_mle.py
# Loading experimental data...
# No convert values
# Starting grid search...
# Computing likelihoods for model (0.0011250000000000001, 0.04875, 0.12499999999999996)...
# Computing likelihoods for model (0.0011250000000000001, 0.04875, 0.14999999999999997)...
# Computing likelihoods for model (0.0011250000000000001, 0.04875, 0.175)...
# Computing likelihoods for model (0.0011250000000000001, 0.0525, 0.12499999999999996)...
# Computing likelihoods for model (0.0011250000000000001, 0.0525, 0.14999999999999997)...
# Computing likelihoods for model (0.0011250000000000001, 0.0525, 0.175)...
# Computing likelihoods for model (0.0011250000000000001, 0.056249999999999994, 0.12499999999999996)...
# Computing likelihoods for model (0.0011250000000000001, 0.056249999999999994, 0.14999999999999997)...
# Computing likelihoods for model (0.0011250000000000001, 0.056249999999999994, 0.175)...
# Computing likelihoods for model (0.0015, 0.04875, 0.12499999999999996)...
# Computing likelihoods for model (0.0015, 0.04875, 0.14999999999999997)...
# Computing likelihoods for model (0.0015, 0.04875, 0.175)...
# Computing likelihoods for model (0.0015, 0.0525, 0.12499999999999996)...
# Computing likelihoods for model (0.0015, 0.0525, 0.14999999999999997)...
# Computing likelihoods for model (0.0015, 0.0525, 0.175)...
# Computing likelihoods for model (0.0015, 0.056249999999999994, 0.12499999999999996)...
# Computing likelihoods for model (0.0015, 0.056249999999999994, 0.14999999999999997)...
# Computing likelihoods for model (0.0015, 0.056249999999999994, 0.175)...
# Computing likelihoods for model (0.001875, 0.04875, 0.12499999999999996)...
# Computing likelihoods for model (0.001875, 0.04875, 0.14999999999999997)...
# Computing likelihoods for model (0.001875, 0.04875, 0.175)...
# Computing likelihoods for model (0.001875, 0.0525, 0.12499999999999996)...
# Computing likelihoods for model (0.001875, 0.0525, 0.14999999999999997)...
# Computing likelihoods for model (0.001875, 0.0525, 0.175)...
# Computing likelihoods for model (0.001875, 0.056249999999999994, 0.12499999999999996)...
# Computing likelihoods for model (0.001875, 0.056249999999999994, 0.14999999999999997)...
# Computing likelihoods for model (0.001875, 0.056249999999999994, 0.175)...
# Finished grid search!
# Optimal d: 0.0015
# Optimal sigma: 0.0525
# Optimal theta: 0.12499999999999996
# Min NLL: 14087.3034128
# PS modification to avoid calculating simulations. To undo, please uncomment last section at /Users/bdmlab/anaconda3/lib/python3.6/site-packages/addm_toolbox/addm_pta_mle.py
# Loading experimental data...
# No convert values
# Starting grid search...
# Computing likelihoods for model (0.0013125, 0.050625, 0.11249999999999996)...
# Computing likelihoods for model (0.0013125, 0.050625, 0.12499999999999996)...
# Computing likelihoods for model (0.0013125, 0.050625, 0.13749999999999996)...
# Computing likelihoods for model (0.0013125, 0.0525, 0.11249999999999996)...
# Computing likelihoods for model (0.0013125, 0.0525, 0.12499999999999996)...
# Computing likelihoods for model (0.0013125, 0.0525, 0.13749999999999996)...
# Computing likelihoods for model (0.0013125, 0.05437499999999999, 0.11249999999999996)...
# Computing likelihoods for model (0.0013125, 0.05437499999999999, 0.12499999999999996)...
# Computing likelihoods for model (0.0013125, 0.05437499999999999, 0.13749999999999996)...
# Computing likelihoods for model (0.0015, 0.050625, 0.11249999999999996)...
# Computing likelihoods for model (0.0015, 0.050625, 0.12499999999999996)...
# Computing likelihoods for model (0.0015, 0.050625, 0.13749999999999996)...
# Computing likelihoods for model (0.0015, 0.0525, 0.11249999999999996)...
# Computing likelihoods for model (0.0015, 0.0525, 0.12499999999999996)...
# Computing likelihoods for model (0.0015, 0.0525, 0.13749999999999996)...
# Computing likelihoods for model (0.0015, 0.05437499999999999, 0.11249999999999996)...
# Computing likelihoods for model (0.0015, 0.05437499999999999, 0.12499999999999996)...
# Computing likelihoods for model (0.0015, 0.05437499999999999, 0.13749999999999996)...
# Computing likelihoods for model (0.0016875, 0.050625, 0.11249999999999996)...
# Computing likelihoods for model (0.0016875, 0.050625, 0.12499999999999996)...
# Computing likelihoods for model (0.0016875, 0.050625, 0.13749999999999996)...
# Computing likelihoods for model (0.0016875, 0.0525, 0.11249999999999996)...
# Computing likelihoods for model (0.0016875, 0.0525, 0.12499999999999996)...
# Computing likelihoods for model (0.0016875, 0.0525, 0.13749999999999996)...
# Computing likelihoods for model (0.0016875, 0.05437499999999999, 0.11249999999999996)...
# Computing likelihoods for model (0.0016875, 0.05437499999999999, 0.12499999999999996)...
# Computing likelihoods for model (0.0016875, 0.05437499999999999, 0.13749999999999996)...
# Finished grid search!
# Optimal d: 0.0015
# Optimal sigma: 0.050625
# Optimal theta: 0.11249999999999996
# Min NLL: 14077.6956356
# PS modification to avoid calculating simulations. To undo, please uncomment last section at /Users/bdmlab/anaconda3/lib/python3.6/site-packages/addm_toolbox/addm_pta_mle.py
# Loading experimental data...
# No convert values
# Starting grid search...
# Computing likelihoods for model (0.00140625, 0.04968750000000001, 0.10624999999999996)...
# Computing likelihoods for model (0.00140625, 0.04968750000000001, 0.11249999999999996)...
# Computing likelihoods for model (0.00140625, 0.04968750000000001, 0.11874999999999997)...
# Computing likelihoods for model (0.00140625, 0.050625, 0.10624999999999996)...
# Computing likelihoods for model (0.00140625, 0.050625, 0.11249999999999996)...
# Computing likelihoods for model (0.00140625, 0.050625, 0.11874999999999997)...
# Computing likelihoods for model (0.00140625, 0.0515625, 0.10624999999999996)...
# Computing likelihoods for model (0.00140625, 0.0515625, 0.11249999999999996)...
# Computing likelihoods for model (0.00140625, 0.0515625, 0.11874999999999997)...
# Computing likelihoods for model (0.0015, 0.04968750000000001, 0.10624999999999996)...
# Computing likelihoods for model (0.0015, 0.04968750000000001, 0.11249999999999996)...
# Computing likelihoods for model (0.0015, 0.04968750000000001, 0.11874999999999997)...
# Computing likelihoods for model (0.0015, 0.050625, 0.10624999999999996)...
# Computing likelihoods for model (0.0015, 0.050625, 0.11249999999999996)...
# Computing likelihoods for model (0.0015, 0.050625, 0.11874999999999997)...
# Computing likelihoods for model (0.0015, 0.0515625, 0.10624999999999996)...
# Computing likelihoods for model (0.0015, 0.0515625, 0.11249999999999996)...
# Computing likelihoods for model (0.0015, 0.0515625, 0.11874999999999997)...
# Computing likelihoods for model (0.0015937500000000001, 0.04968750000000001, 0.10624999999999996)...
# Computing likelihoods for model (0.0015937500000000001, 0.04968750000000001, 0.11249999999999996)...
# Computing likelihoods for model (0.0015937500000000001, 0.04968750000000001, 0.11874999999999997)...
# Computing likelihoods for model (0.0015937500000000001, 0.050625, 0.10624999999999996)...
# Computing likelihoods for model (0.0015937500000000001, 0.050625, 0.11249999999999996)...
# Computing likelihoods for model (0.0015937500000000001, 0.050625, 0.11874999999999997)...
# Computing likelihoods for model (0.0015937500000000001, 0.0515625, 0.10624999999999996)...
# Computing likelihoods for model (0.0015937500000000001, 0.0515625, 0.11249999999999996)...
# Computing likelihoods for model (0.0015937500000000001, 0.0515625, 0.11874999999999997)...
# Finished grid search!
# Optimal d: 0.0015
# Optimal sigma: 0.0515625
# Optimal theta: 0.10624999999999996
# Min NLL: 14073.7547164
# PS modification to avoid calculating simulations. To undo, please uncomment last section at /Users/bdmlab/anaconda3/lib/python3.6/site-packages/addm_toolbox/addm_pta_mle.py
# Loading experimental data...
# No convert values
# Starting grid search...
# Computing likelihoods for model (0.001453125, 0.05109375, 0.10312499999999995)...
# Computing likelihoods for model (0.001453125, 0.05109375, 0.10624999999999996)...
# Computing likelihoods for model (0.001453125, 0.05109375, 0.10937499999999996)...
# Computing likelihoods for model (0.001453125, 0.0515625, 0.10312499999999995)...
# Computing likelihoods for model (0.001453125, 0.0515625, 0.10624999999999996)...
# Computing likelihoods for model (0.001453125, 0.0515625, 0.10937499999999996)...
# Computing likelihoods for model (0.001453125, 0.052031249999999994, 0.10312499999999995)...
# Computing likelihoods for model (0.001453125, 0.052031249999999994, 0.10624999999999996)...
# Computing likelihoods for model (0.001453125, 0.052031249999999994, 0.10937499999999996)...
# Computing likelihoods for model (0.0015, 0.05109375, 0.10312499999999995)...
# Computing likelihoods for model (0.0015, 0.05109375, 0.10624999999999996)...
# Computing likelihoods for model (0.0015, 0.05109375, 0.10937499999999996)...
# Computing likelihoods for model (0.0015, 0.0515625, 0.10312499999999995)...
# Computing likelihoods for model (0.0015, 0.0515625, 0.10624999999999996)...
# Computing likelihoods for model (0.0015, 0.0515625, 0.10937499999999996)...
# Computing likelihoods for model (0.0015, 0.052031249999999994, 0.10312499999999995)...
# Computing likelihoods for model (0.0015, 0.052031249999999994, 0.10624999999999996)...
# Computing likelihoods for model (0.0015, 0.052031249999999994, 0.10937499999999996)...
# Computing likelihoods for model (0.001546875, 0.05109375, 0.10312499999999995)...
# Computing likelihoods for model (0.001546875, 0.05109375, 0.10624999999999996)...
# Computing likelihoods for model (0.001546875, 0.05109375, 0.10937499999999996)...
# Computing likelihoods for model (0.001546875, 0.0515625, 0.10312499999999995)...
# Computing likelihoods for model (0.001546875, 0.0515625, 0.10624999999999996)...
# Computing likelihoods for model (0.001546875, 0.0515625, 0.10937499999999996)...
# Computing likelihoods for model (0.001546875, 0.052031249999999994, 0.10312499999999995)...
# Computing likelihoods for model (0.001546875, 0.052031249999999994, 0.10624999999999996)...
# Computing likelihoods for model (0.001546875, 0.052031249999999994, 0.10937499999999996)...
# Finished grid search!
# Optimal d: 0.0015
# Optimal sigma: 0.05109375
# Optimal theta: 0.10312499999999995
# Min NLL: 14071.7406799
# PS modification to avoid calculating simulations. To undo, please uncomment last section at /Users/bdmlab/anaconda3/lib/python3.6/site-packages/addm_toolbox/addm_pta_mle.py
# Loading experimental data...
# No convert values
# Starting grid search...
# Computing likelihoods for model (0.0014765625, 0.050859375, 0.10156249999999994)...
# Computing likelihoods for model (0.0014765625, 0.050859375, 0.10312499999999995)...
# Computing likelihoods for model (0.0014765625, 0.050859375, 0.10468749999999996)...
# Computing likelihoods for model (0.0014765625, 0.05109375, 0.10156249999999994)...
# Computing likelihoods for model (0.0014765625, 0.05109375, 0.10312499999999995)...
# Computing likelihoods for model (0.0014765625, 0.05109375, 0.10468749999999996)...
# Computing likelihoods for model (0.0014765625, 0.051328125, 0.10156249999999994)...
# Computing likelihoods for model (0.0014765625, 0.051328125, 0.10312499999999995)...
# Computing likelihoods for model (0.0014765625, 0.051328125, 0.10468749999999996)...
# Computing likelihoods for model (0.0015, 0.050859375, 0.10156249999999994)...
# Computing likelihoods for model (0.0015, 0.050859375, 0.10312499999999995)...
# Computing likelihoods for model (0.0015, 0.050859375, 0.10468749999999996)...
# Computing likelihoods for model (0.0015, 0.05109375, 0.10156249999999994)...
# Computing likelihoods for model (0.0015, 0.05109375, 0.10312499999999995)...
# Computing likelihoods for model (0.0015, 0.05109375, 0.10468749999999996)...
# Computing likelihoods for model (0.0015, 0.051328125, 0.10156249999999994)...
# Computing likelihoods for model (0.0015, 0.051328125, 0.10312499999999995)...
# Computing likelihoods for model (0.0015, 0.051328125, 0.10468749999999996)...
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-5756:
# Traceback (most recent call last):
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# Traceback (most recent call last):
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/addm_toolbox/addm.py", line 117, in unwrap_addm_get_trial_likelihood
#     return aDDM.get_trial_likelihood(*arg, **kwarg)
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/addm_toolbox/addm.py", line 251, in get_trial_likelihood
#     np.dot(norm.pdf(changeMatrix, mean, self.sigma),
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/scipy/stats/_distn_infrastructure.py", line 1653, in pdf
#     output = zeros(shape(cond), dtyp)
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/addm_toolbox/addm.py", line 117, in unwrap_addm_get_trial_likelihood
#     return aDDM.get_trial_likelihood(*arg, **kwarg)
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/addm_toolbox/addm.py", line 117, in unwrap_addm_get_trial_likelihood
#     return aDDM.get_trial_likelihood(*arg, **kwarg)
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/addm_toolbox/addm.py", line 251, in get_trial_likelihood
#     np.dot(norm.pdf(changeMatrix, mean, self.sigma),
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/addm_toolbox/addm.py", line 266, in get_trial_likelihood
#     norm.cdf(changeDown[:, time], mean, self.sigma))
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/scipy/stats/_distn_infrastructure.py", line 1646, in pdf
#     x, loc, scale = map(asarray, (x, loc, scale))
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/scipy/stats/_distn_infrastructure.py", line 1740, in cdf
#     if np.any(cond):  # call only if at least 1 entry
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/numpy/core/fromnumeric.py", line 1848, in any
#     return arr.any(axis=axis, out=out, keepdims=keepdims)
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/numpy/core/numeric.py", line 462, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/numpy/core/_methods.py", line 38, in _any
#     return umr_any(a, axis, dtype, out, keepdims)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/addm_toolbox/addm.py", line 117, in unwrap_addm_get_trial_likelihood
#     return aDDM.get_trial_likelihood(*arg, **kwarg)
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/addm_toolbox/addm.py", line 251, in get_trial_likelihood
#     np.dot(norm.pdf(changeMatrix, mean, self.sigma),
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/scipy/stats/_distn_infrastructure.py", line 1658, in pdf
#     place(output, cond, self._pdf(*goodargs) / scale)
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/addm_toolbox/addm.py", line 117, in unwrap_addm_get_trial_likelihood
#     return aDDM.get_trial_likelihood(*arg, **kwarg)
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py", line 1484, in place
#     return _insert(arr, mask, vals)
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/addm_toolbox/addm.py", line 266, in get_trial_likelihood
#     norm.cdf(changeDown[:, time], mean, self.sigma))
# KeyboardInterrupt
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/scipy/stats/_distn_infrastructure.py", line 1738, in cdf
#     place(output, (1-cond0)+np.isnan(x), self.badvalue)
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py", line 1484, in place
#     return _insert(arr, mask, vals)
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/addm_toolbox/addm.py", line 117, in unwrap_addm_get_trial_likelihood
#     return aDDM.get_trial_likelihood(*arg, **kwarg)
# KeyboardInterrupt
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/addm_toolbox/addm.py", line 269, in get_trial_likelihood
#     sumIn = np.sum(prStates[:, time-1])
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/numpy/core/fromnumeric.py", line 1724, in sum
#     out=out, keepdims=keepdims)
# KeyboardInterrupt
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/numpy/core/_methods.py", line 32, in _sum
#     return umr_sum(a, axis, dtype, out, keepdims)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-030a04ed6209> in <module>()
#      40                       trials_per_subject,simulations_per_condition, [],
#      41                       9, True, True,
# ---> 42                       True)
#      43
#      44     # Update the NLL values for this iteration
#
# ~/anaconda/lib/python3.5/site-packages/addm_toolbox/addm_pta_mle_limited.py in main(rangeD, rangeSigma, rangeTheta, trialsFileName, expdataFileName, fixationsFileName, trialsPerSubject, simulationsPerCondition, subjectIds, numThreads, saveSimulations, saveFigures, verbose)
#     125         try:
#     126             likelihoods[model.params] = model.parallel_get_likelihoods(
# --> 127                 dataTrials, numThreads=numThreads)
#     128         except:
#     129             print(u"An exception occurred during the likelihood "
#
# ~/anaconda/lib/python3.5/site-packages/addm_toolbox/addm.py in parallel_get_likelihoods(self, trials, timeStep, stateStep, numThreads)
#     320                                    trials,
#     321                                    [timeStep] * len(trials),
# --> 322                                    [stateStep] * len(trials)))
#     323         pool.close()
#     324         return likelihoods
#
# ~/anaconda/lib/python3.5/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     264         in a list that is returned.
#     265         '''
# --> 266         return self._map_async(func, iterable, mapstar, chunksize).get()
#     267
#     268     def starmap(self, func, iterable, chunksize=None):
#
# ~/anaconda/lib/python3.5/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# ~/anaconda/lib/python3.5/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# ~/anaconda/lib/python3.5/threading.py in wait(self, timeout)
#     547             signaled = self._flag
#     548             if not signaled:
# --> 549                 signaled = self._cond.wait(timeout)
#     550             return signaled
#     551
#
# ~/anaconda/lib/python3.5/threading.py in wait(self, timeout)
#     291         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     292             if timeout is None:
# --> 293                 waiter.acquire()
#     294                 gotit = True
#     295             else:
#
# KeyboardInterrupt:
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# Process ForkPoolWorker-5769:
# Process ForkPoolWorker-5763:
# Process ForkPoolWorker-5764:
# Process ForkPoolWorker-5766:
# Process ForkPoolWorker-5767:
# Process ForkPoolWorker-5765:
# Process ForkPoolWorker-5768:
# Process ForkPoolWorker-5762:
# Process ForkPoolWorker-5761:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
# KeyboardInterrupt
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt

# %%
iterations_dislike = iteration_dataf
iterations_dislike
# Out:
#     Iteration         d     sigma     theta       min_NLL
# 0           1  0.003000  0.060000  0.300000  14426.320831
# 1           2  0.001500  0.060000  0.200000  14249.165216
# 2           3  0.001500  0.052500  0.150000  14100.560179
# 3           4  0.001500  0.052500  0.125000  14087.303413
# 4           5  0.001500  0.050625  0.112500  14077.695636
# 5           6  0.001500  0.051562  0.106250  14073.754716
# 6           7  0.001500  0.051094  0.103125  14071.740680
# 7           8  0.001523  0.051094  0.101562  14070.888601
# 8           9  0.001523  0.051211  0.100781  14070.439959
# 9          10  0.001523  0.051211  0.100391  14070.227052
# 10         11  0.001521  0.051182  0.100195  14070.118659
# 11         12  0.001521  0.051182  0.100098  14070.065485
# 12         13  0.001521  0.051182  0.100049  14070.038874
# 13         14  0.001521  0.051185  0.100024  14070.025566
# 14         15  0.001521  0.051183  0.100012  14070.018914
# 15         16  0.001521  0.051184  0.100006  14070.015589
# 16         17  0.001521  0.051184  0.100003  14070.013926
# 17         18  0.001521  0.051184  0.100002  14070.013095
# 18         19  0.001521  0.051184  0.100001  14070.012679
# 19         20  0.001521  0.051184  0.100000  14070.012472
# 20         21  0.001521  0.051184  0.100000  14070.012368
# 21         22  0.001521  0.051184  0.100000  14070.012316
# 22         23  0.001521  0.051184  0.100000  14070.012290

# %% [markdown]
# ## Like condition grid iterations

# %%
iteration_data = []
current_min_nll = 0
previous_min_nll = 0


# Initial grid selection
range_d = [0.003, 0.006, 0.009]
range_sigma = [0.03, 0.06, 0.09]
range_theta = [0.3, 0.5, 0.7]

#data files definition
trials_file_name = None
#expdata_file_name = '/Users/bdmlab/OneDrive - University College London/PhD Projects/GiTs/FF2018/InputData/expdata_FFA_Like_v2.csv'
#fixations_file_name = '/Users/bdmlab/OneDrive - University College London/PhD Projects/GiTs/FF2018/InputData/fixations_FFA_Like_v2.csv'

expdata_file_name = '/Users/pradyumna/Documents/gitDocs/FF2018/InputData/expdata_FFA_Like_v2.csv'
fixations_file_name = '/Users/pradyumna/Documents/gitDocs/FF2018/InputData/fixations_FFA_Like_v2.csv'



trials_per_subject = 120
simulations_per_condition = 300

iter_num = 1

while [(abs(current_min_nll-previous_min_nll) > (previous_min_nll*1/100)) and ((current_min_nll-previous_min_nll)>0) ]  or iter_num == 1:
    
    if iter_num > 1:
        delta_d = range_d[1]-range_d[0]
        delta_sigma = range_sigma[1] - range_sigma[0]
        delta_theta = range_theta[1] - range_theta[0]
        
        range_d = [new_d - delta_d/2 , new_d ,new_d + delta_d/2]
        range_sigma =[new_sigma - delta_sigma/2 , new_sigma ,new_sigma + delta_sigma/2]
        range_theta =[new_theta - delta_theta/2 , new_theta ,new_theta + delta_theta/2]
    
    
    #run the toolbox
    a = addm_pta_mle_limited.main(range_d, range_sigma, range_theta,
                      None, 
                      expdata_file_name,
                      fixations_file_name, 
                      trials_per_subject,simulations_per_condition, [],
                      9, True, True,
                      True)
    
    # Update the NLL values for this iteration
    previous_min_nll = current_min_nll
    current_min_nll = a[1]
    
    #get the new values
    new_d = a[0][0]
    new_sigma = a[0][1]
    new_theta = a[0][2]
    
    iteration_data.append([iter_num,new_d, new_sigma, new_theta,current_min_nll]) 

    iter_num = iter_num + 1



    
    
iteration_dataf=pd.DataFrame(iteration_data,columns=['Iteration', 'd', 'sigma', 'theta', 'min_NLL'])
print ("Finished iterations!!")
# Out:
# Loading experimental data...
# No convert values
# Starting grid search...
# Computing likelihoods for model (0.003, 0.03, 0.3)...
# Computing likelihoods for model (0.003, 0.03, 0.5)...
# Computing likelihoods for model (0.003, 0.03, 0.7)...
# Computing likelihoods for model (0.003, 0.06, 0.3)...
# Computing likelihoods for model (0.003, 0.06, 0.5)...
# Computing likelihoods for model (0.003, 0.06, 0.7)...
# Computing likelihoods for model (0.003, 0.09, 0.3)...
# Computing likelihoods for model (0.003, 0.09, 0.5)...
# Computing likelihoods for model (0.003, 0.09, 0.7)...
# Computing likelihoods for model (0.006, 0.03, 0.3)...
# Computing likelihoods for model (0.006, 0.03, 0.5)...
# Computing likelihoods for model (0.006, 0.03, 0.7)...
# Computing likelihoods for model (0.006, 0.06, 0.3)...
# Computing likelihoods for model (0.006, 0.06, 0.5)...
# Computing likelihoods for model (0.006, 0.06, 0.7)...
# Computing likelihoods for model (0.006, 0.09, 0.3)...
# Computing likelihoods for model (0.006, 0.09, 0.5)...
# Computing likelihoods for model (0.006, 0.09, 0.7)...
# Computing likelihoods for model (0.009, 0.03, 0.3)...
# Computing likelihoods for model (0.009, 0.03, 0.5)...
# Computing likelihoods for model (0.009, 0.03, 0.7)...
# Computing likelihoods for model (0.009, 0.06, 0.3)...
# Computing likelihoods for model (0.009, 0.06, 0.5)...
# Computing likelihoods for model (0.009, 0.06, 0.7)...
# Computing likelihoods for model (0.009, 0.09, 0.3)...
# Computing likelihoods for model (0.009, 0.09, 0.5)...
# Computing likelihoods for model (0.009, 0.09, 0.7)...
# Finished grid search!
# Optimal d: 0.003
# Optimal sigma: 0.06
# Optimal theta: 0.3
# Min NLL: 13446.111235
# PS modification to avoid calculating simulations. To undo, please uncomment last section at /Users/bdmlab/anaconda3/lib/python3.6/site-packages/addm_toolbox/addm_pta_mle.py
# Loading experimental data...
# No convert values
# Starting grid search...
# Computing likelihoods for model (0.0015, 0.045, 0.19999999999999998)...
# Computing likelihoods for model (0.0015, 0.045, 0.3)...
# Computing likelihoods for model (0.0015, 0.045, 0.4)...
# Computing likelihoods for model (0.0015, 0.06, 0.19999999999999998)...
# Computing likelihoods for model (0.0015, 0.06, 0.3)...
# Computing likelihoods for model (0.0015, 0.06, 0.4)...
# Computing likelihoods for model (0.0015, 0.075, 0.19999999999999998)...
# Computing likelihoods for model (0.0015, 0.075, 0.3)...
# Computing likelihoods for model (0.0015, 0.075, 0.4)...
# Computing likelihoods for model (0.003, 0.045, 0.19999999999999998)...
# Computing likelihoods for model (0.003, 0.045, 0.3)...
# Computing likelihoods for model (0.003, 0.045, 0.4)...
# Computing likelihoods for model (0.003, 0.06, 0.19999999999999998)...
# Computing likelihoods for model (0.003, 0.06, 0.3)...
# Computing likelihoods for model (0.003, 0.06, 0.4)...
# Computing likelihoods for model (0.003, 0.075, 0.19999999999999998)...
# Computing likelihoods for model (0.003, 0.075, 0.3)...
# Computing likelihoods for model (0.003, 0.075, 0.4)...
# Computing likelihoods for model (0.0045000000000000005, 0.045, 0.19999999999999998)...
# Computing likelihoods for model (0.0045000000000000005, 0.045, 0.3)...
# Computing likelihoods for model (0.0045000000000000005, 0.045, 0.4)...
# Computing likelihoods for model (0.0045000000000000005, 0.06, 0.19999999999999998)...
# Computing likelihoods for model (0.0045000000000000005, 0.06, 0.3)...
# Computing likelihoods for model (0.0045000000000000005, 0.06, 0.4)...
# Computing likelihoods for model (0.0045000000000000005, 0.075, 0.19999999999999998)...
# Computing likelihoods for model (0.0045000000000000005, 0.075, 0.3)...
# Computing likelihoods for model (0.0045000000000000005, 0.075, 0.4)...
# Finished grid search!
# Optimal d: 0.0045000000000000005
# Optimal sigma: 0.045
# Optimal theta: 0.19999999999999998
# Min NLL: 13274.6544156
# PS modification to avoid calculating simulations. To undo, please uncomment last section at /Users/bdmlab/anaconda3/lib/python3.6/site-packages/addm_toolbox/addm_pta_mle.py
# Loading experimental data...
# No convert values
# Starting grid search...
# Computing likelihoods for model (0.0037500000000000007, 0.0375, 0.14999999999999997)...
# Computing likelihoods for model (0.0037500000000000007, 0.0375, 0.19999999999999998)...
# Computing likelihoods for model (0.0037500000000000007, 0.0375, 0.25)...
# Computing likelihoods for model (0.0037500000000000007, 0.045, 0.14999999999999997)...
# Computing likelihoods for model (0.0037500000000000007, 0.045, 0.19999999999999998)...
# Computing likelihoods for model (0.0037500000000000007, 0.045, 0.25)...
# Computing likelihoods for model (0.0037500000000000007, 0.0525, 0.14999999999999997)...
# Computing likelihoods for model (0.0037500000000000007, 0.0525, 0.19999999999999998)...
# Computing likelihoods for model (0.0037500000000000007, 0.0525, 0.25)...
# Computing likelihoods for model (0.0045000000000000005, 0.0375, 0.14999999999999997)...
# Computing likelihoods for model (0.0045000000000000005, 0.0375, 0.19999999999999998)...
# Computing likelihoods for model (0.0045000000000000005, 0.0375, 0.25)...
# Computing likelihoods for model (0.0045000000000000005, 0.045, 0.14999999999999997)...
# Computing likelihoods for model (0.0045000000000000005, 0.045, 0.19999999999999998)...
# Computing likelihoods for model (0.0045000000000000005, 0.045, 0.25)...
# Computing likelihoods for model (0.0045000000000000005, 0.0525, 0.14999999999999997)...
# Computing likelihoods for model (0.0045000000000000005, 0.0525, 0.19999999999999998)...
# Computing likelihoods for model (0.0045000000000000005, 0.0525, 0.25)...
# Computing likelihoods for model (0.00525, 0.0375, 0.14999999999999997)...
# Computing likelihoods for model (0.00525, 0.0375, 0.19999999999999998)...
# Computing likelihoods for model (0.00525, 0.0375, 0.25)...
# Computing likelihoods for model (0.00525, 0.045, 0.14999999999999997)...
# Computing likelihoods for model (0.00525, 0.045, 0.19999999999999998)...
# Computing likelihoods for model (0.00525, 0.045, 0.25)...
# Computing likelihoods for model (0.00525, 0.0525, 0.14999999999999997)...
# Computing likelihoods for model (0.00525, 0.0525, 0.19999999999999998)...
# Computing likelihoods for model (0.00525, 0.0525, 0.25)...
# Finished grid search!
# Optimal d: 0.0037500000000000007
# Optimal sigma: 0.0525
# Optimal theta: 0.14999999999999997
# Min NLL: 13195.8306612
# PS modification to avoid calculating simulations. To undo, please uncomment last section at /Users/bdmlab/anaconda3/lib/python3.6/site-packages/addm_toolbox/addm_pta_mle.py
# Loading experimental data...
# No convert values
# Starting grid search...
# Computing likelihoods for model (0.003375000000000001, 0.04875, 0.12499999999999996)...
# Computing likelihoods for model (0.003375000000000001, 0.04875, 0.14999999999999997)...
# Computing likelihoods for model (0.003375000000000001, 0.04875, 0.175)...
# Computing likelihoods for model (0.003375000000000001, 0.0525, 0.12499999999999996)...
# Computing likelihoods for model (0.003375000000000001, 0.0525, 0.14999999999999997)...
# Computing likelihoods for model (0.003375000000000001, 0.0525, 0.175)...
# Computing likelihoods for model (0.003375000000000001, 0.056249999999999994, 0.12499999999999996)...
# Computing likelihoods for model (0.003375000000000001, 0.056249999999999994, 0.14999999999999997)...
# Computing likelihoods for model (0.003375000000000001, 0.056249999999999994, 0.175)...
# Computing likelihoods for model (0.0037500000000000007, 0.04875, 0.12499999999999996)...
# Computing likelihoods for model (0.0037500000000000007, 0.04875, 0.14999999999999997)...
# Computing likelihoods for model (0.0037500000000000007, 0.04875, 0.175)...
# Computing likelihoods for model (0.0037500000000000007, 0.0525, 0.12499999999999996)...
# Computing likelihoods for model (0.0037500000000000007, 0.0525, 0.14999999999999997)...
# Computing likelihoods for model (0.0037500000000000007, 0.0525, 0.175)...
# Computing likelihoods for model (0.0037500000000000007, 0.056249999999999994, 0.12499999999999996)...
# Computing likelihoods for model (0.0037500000000000007, 0.056249999999999994, 0.14999999999999997)...
# Computing likelihoods for model (0.0037500000000000007, 0.056249999999999994, 0.175)...
# Computing likelihoods for model (0.004125, 0.04875, 0.12499999999999996)...
# Computing likelihoods for model (0.004125, 0.04875, 0.14999999999999997)...
# Computing likelihoods for model (0.004125, 0.04875, 0.175)...
# Computing likelihoods for model (0.004125, 0.0525, 0.12499999999999996)...
# Computing likelihoods for model (0.004125, 0.0525, 0.14999999999999997)...
# Computing likelihoods for model (0.004125, 0.0525, 0.175)...
# Computing likelihoods for model (0.004125, 0.056249999999999994, 0.12499999999999996)...
# Computing likelihoods for model (0.004125, 0.056249999999999994, 0.14999999999999997)...
# Computing likelihoods for model (0.004125, 0.056249999999999994, 0.175)...
# Finished grid search!
# Optimal d: 0.0037500000000000007
# Optimal sigma: 0.04875
# Optimal theta: 0.12499999999999996
# Min NLL: 13164.1694278
# PS modification to avoid calculating simulations. To undo, please uncomment last section at /Users/bdmlab/anaconda3/lib/python3.6/site-packages/addm_toolbox/addm_pta_mle.py
# Loading experimental data...
# No convert values
# Starting grid search...
# Computing likelihoods for model (0.0035625000000000006, 0.046875, 0.11249999999999996)...
# Computing likelihoods for model (0.0035625000000000006, 0.046875, 0.12499999999999996)...
# Computing likelihoods for model (0.0035625000000000006, 0.046875, 0.13749999999999996)...
# Computing likelihoods for model (0.0035625000000000006, 0.04875, 0.11249999999999996)...
# Computing likelihoods for model (0.0035625000000000006, 0.04875, 0.12499999999999996)...
# Computing likelihoods for model (0.0035625000000000006, 0.04875, 0.13749999999999996)...
# Computing likelihoods for model (0.0035625000000000006, 0.050625, 0.11249999999999996)...
# Computing likelihoods for model (0.0035625000000000006, 0.050625, 0.12499999999999996)...
# Computing likelihoods for model (0.0035625000000000006, 0.050625, 0.13749999999999996)...
# Computing likelihoods for model (0.0037500000000000007, 0.046875, 0.11249999999999996)...
# Computing likelihoods for model (0.0037500000000000007, 0.046875, 0.12499999999999996)...
# Computing likelihoods for model (0.0037500000000000007, 0.046875, 0.13749999999999996)...
# Computing likelihoods for model (0.0037500000000000007, 0.04875, 0.11249999999999996)...
# Computing likelihoods for model (0.0037500000000000007, 0.04875, 0.12499999999999996)...
# Computing likelihoods for model (0.0037500000000000007, 0.04875, 0.13749999999999996)...
# Computing likelihoods for model (0.0037500000000000007, 0.050625, 0.11249999999999996)...
# Computing likelihoods for model (0.0037500000000000007, 0
...
# Computing likelihoods for model (0.003871398925781251, 0.049107055664062496, 0.10000305175781238)...
# Computing likelihoods for model (0.003871398925781251, 0.049107055664062496, 0.10000610351562489)...
# Computing likelihoods for model (0.003871398925781251, 0.049107055664062496, 0.1000091552734374)...
# Computing likelihoods for model (0.003871398925781251, 0.04910751342773437, 0.10000305175781238)...
# Computing likelihoods for model (0.003871398925781251, 0.04910751342773437, 0.10000610351562489)...
# Computing likelihoods for model (0.003871398925781251, 0.04910751342773437, 0.1000091552734374)...
# Computing likelihoods for model (0.0038714447021484383, 0.049106597900390625, 0.10000305175781238)...
# Computing likelihoods for model (0.0038714447021484383, 0.049106597900390625, 0.10000610351562489)...
# Computing likelihoods for model (0.0038714447021484383, 0.049106597900390625, 0.1000091552734374)...
# Computing likelihoods for model (0.0038714447021484383, 0.049107055664062496, 0.10000305175781238)...
# Computing likelihoods for model (0.0038714447021484383, 0.049107055664062496, 0.10000610351562489)...
# Computing likelihoods for model (0.0038714447021484383, 0.049107055664062496, 0.1000091552734374)...
# Computing likelihoods for model (0.0038714447021484383, 0.04910751342773437, 0.10000305175781238)...
# Computing likelihoods for model (0.0038714447021484383, 0.04910751342773437, 0.10000610351562489)...
# Computing likelihoods for model (0.0038714447021484383, 0.04910751342773437, 0.1000091552734374)...
# Finished grid search!
# Optimal d: 0.003871398925781251
# Optimal sigma: 0.049106597900390625
# Optimal theta: 0.10000305175781238
# Min NLL: 13156.9207467
# PS modification to avoid calculating simulations. To undo, please uncomment last section at /Users/bdmlab/anaconda3/lib/python3.6/site-packages/addm_toolbox/addm_pta_mle.py
# Loading experimental data...
# No convert values
# Starting grid search...
# Computing likelihoods for model (0.0038713760375976573, 0.04910636901855469, 0.10000152587890612)...
# ...
# Computing likelihoods for model (0.0038713855681708096, 0.04910668336437084, 0.10000000002328283)...
# Computing likelihoods for model (0.0038713855681708096, 0.04910668336437084, 0.1000000000465659)...
# Process ForkPoolWorker-14018:
# An exception occurred during the likelihood computations for model (0.0038713855681708096, 0.04910668336437084, 0.1000000000465659).
# Process ForkPoolWorker-14015:
# Process ForkPoolWorker-14014:
# Process ForkPoolWorker-14016:
# Process ForkPoolWorker-14019:
# Process ForkPoolWorker-14022:
# Process ForkPoolWorker-14021:
# Process ForkPoolWorker-14020:
# Process ForkPoolWorker-14017:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-edcc727ff9b2> in <module>()
#      43                       trials_per_subject,simulations_per_condition, [],
#      44                       9, True, True,
# ---> 45                       True)
#      46
#      47     # Update the NLL values for this iteration
#
# ~/anaconda/lib/python3.5/site-packages/addm_toolbox/addm_pta_mle_limited.py in main(rangeD, rangeSigma, rangeTheta, trialsFileName, expdataFileName, fixationsFileName, trialsPerSubject, simulationsPerCondition, subjectIds, numThreads, saveSimulations, saveFigures, verbose)
#     125         try:
#     126             likelihoods[model.params] = model.parallel_get_likelihoods(
# --> 127                 dataTrials, numThreads=numThreads)
#     128         except:
#     129             print(u"An exception occurred during the likelihood "
#
# ~/anaconda/lib/python3.5/site-packages/addm_toolbox/addm.py in parallel_get_likelihoods(self, trials, timeStep, stateStep, numThreads)
#     320                                    trials,
#     321                                    [timeStep] * len(trials),
# --> 322                                    [stateStep] * len(trials)))
#     323         pool.close()
#     324         return likelihoods
#
# ~/anaconda/lib/python3.5/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     264         in a list that is returned.
#     265         '''
# --> 266         return self._map_async(func, iterable, mapstar, chunksize).get()
#     267
#     268     def starmap(self, func, iterable, chunksize=None):
#
# ~/anaconda/lib/python3.5/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# ~/anaconda/lib/python3.5/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# ~/anaconda/lib/python3.5/threading.py in wait(self, timeout)
#     547             signaled = self._flag
#     548             if not signaled:
# --> 549                 signaled = self._cond.wait(timeout)
#     550             return signaled
#     551
#
# ~/anaconda/lib/python3.5/threading.py in wait(self, timeout)
#     291         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     292             if timeout is None:
# --> 293                 waiter.acquire()
#     294                 gotit = True
#     295             else:
#
# KeyboardInterrupt:
# Traceback (most recent call last):
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# Traceback (most recent call last):
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/addm_toolbox/addm.py", line 117, in unwrap_addm_get_trial_likelihood
#     return aDDM.get_trial_likelihood(*arg, **kwarg)
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/addm_toolbox/addm.py", line 251, in get_trial_likelihood
#     np.dot(norm.pdf(changeMatrix, mean, self.sigma),
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/scipy/stats/_distn_infrastructure.py", line 1647, in pdf
#     args = tuple(map(asarray, args))
# KeyboardInterrupt
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/addm_toolbox/addm.py", line 117, in unwrap_addm_get_trial_likelihood
#     return aDDM.get_trial_likelihood(*arg, **kwarg)
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/addm_toolbox/addm.py", line 251, in get_trial_likelihood
#     np.dot(norm.pdf(changeMatrix, mean, self.sigma),
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/scipy/stats/_distn_infrastructure.py", line 1648, in pdf
#     dtyp = np.find_common_type([x.dtype, np.float64], [])
# Traceback (most recent call last):
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/addm_toolbox/addm.py", line 117, in unwrap_addm_get_trial_likelihood
#     return aDDM.get_trial_likelihood(*arg, **kwarg)
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/addm_toolbox/addm.py", line 117, in unwrap_addm_get_trial_likelihood
#     return aDDM.get_trial_likelihood(*arg, **kwarg)
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/addm_toolbox/addm.py", line 117, in unwrap_addm_get_trial_likelihood
#     return aDDM.get_trial_likelihood(*arg, **kwarg)
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/addm_toolbox/addm.py", line 251, in get_trial_likelihood
#     np.dot(norm.pdf(changeMatrix, mean, self.sigma),
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/addm_toolbox/addm.py", line 251, in get_trial_likelihood
#     np.dot(norm.pdf(changeMatrix, mean, self.sigma),
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/addm_toolbox/addm.py", line 117, in unwrap_addm_get_trial_likelihood
#     return aDDM.get_trial_likelihood(*arg, **kwarg)
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/scipy/stats/_distn_infrastructure.py", line 1654, in pdf
#     putmask(output, (1-cond0)+np.isnan(x), self.badvalue)
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/scipy/stats/_distn_infrastructure.py", line 1658, in pdf
#     place(output, cond, self._pdf(*goodargs) / scale)
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# KeyboardInterrupt
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/scipy/stats/_continuous_distns.py", line 135, in _pdf
#     return _norm_pdf(x)
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/addm_toolbox/addm.py", line 266, in get_trial_likelihood
#     norm.cdf(changeDown[:, time], mean, self.sigma))
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/scipy/stats/_continuous_distns.py", line 77, in _norm_pdf
#     return np.exp(-x**2/2.0) / _norm_pdf_C
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/addm_toolbox/addm.py", line 117, in unwrap_addm_get_trial_likelihood
#     return aDDM.get_trial_likelihood(*arg, **kwarg)
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/scipy/stats/_distn_infrastructure.py", line 1741, in cdf
#     goodargs = argsreduce(cond, *((x,)+args))
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/addm_toolbox/addm.py", line 251, in get_trial_likelihood
#     np.dot(norm.pdf(changeMatrix, mean, self.sigma),
# Traceback (most recent call last):
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/scipy/stats/_distn_infrastructure.py", line 549, in argsreduce
#     return [np.extract(cond, arr1 * expand_arr) for arr1 in newargs]
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/scipy/stats/_distn_infrastructure.py", line 549, in <listcomp>
#     return [np.extract(cond, arr1 * expand_arr) for arr1 in newargs]
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/scipy/stats/_distn_infrastructure.py", line 1646, in pdf
#     x, loc, scale = map(asarray, (x, loc, scale))
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/numpy/core/numeric.py", line 462, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/addm_toolbox/addm.py", line 286, in get_trial_likelihood
#     if trial.choice == -1:  # Choice was left.
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/addm_toolbox/addm.py", line 117, in unwrap_addm_get_trial_likelihood
#     return aDDM.get_trial_likelihood(*arg, **kwarg)
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/addm_toolbox/addm.py", line 263, in get_trial_likelihood
#     (1 - norm.cdf(changeUp[:, time], mean, self.sigma)))
#   File "/Users/pradyumna/anaconda/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# KeyboardInterrupt
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/addm_toolbox/addm.py", line 117, in unwrap_addm_get_trial_likelihood
#     return aDDM.get_trial_likelihood(*arg, **kwarg)
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/numpy/core/numerictypes.py", line 1024, in find_common_type
#     maxa = _can_coerce_all(array_types)
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/addm_toolbox/addm.py", line 251, in get_trial_likelihood
#     np.dot(norm.pdf(changeMatrix, mean, self.sigma),
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/scipy/stats/_distn_infrastructure.py", line 1741, in cdf
#     goodargs = argsreduce(cond, *((x,)+args))
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/numpy/core/numerictypes.py", line 958, in _can_coerce_all
#     numcoerce = len([x for x in dtypelist if newdtype >= x])
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/scipy/stats/_distn_infrastructure.py", line 1656, in pdf
#     goodargs = argsreduce(cond, *((x,)+args+(scale,)))
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/numpy/core/numerictypes.py", line 958, in <listcomp>
#     numcoerce = len([x for x in dtypelist if newdtype >= x])
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/scipy/stats/_distn_infrastructure.py", line 549, in argsreduce
#     return [np.extract(cond, arr1 * expand_arr) for arr1 in newargs]
# KeyboardInterrupt
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/scipy/stats/_distn_infrastructure.py", line 549, in argsreduce
#     return [np.extract(cond, arr1 * expand_arr) for arr1 in newargs]
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/scipy/stats/_distn_infrastructure.py", line 549, in <listcomp>
#     return [np.extract(cond, arr1 * expand_arr) for arr1 in newargs]
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/scipy/stats/_distn_infrastructure.py", line 549, in <listcomp>
#     return [np.extract(cond, arr1 * expand_arr) for arr1 in newargs]
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py", line 1446, in extract
#     return _nx.take(ravel(arr), nonzero(ravel(condition))[0])
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py", line 1446, in extract
#     return _nx.take(ravel(arr), nonzero(ravel(condition))[0])
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/numpy/core/fromnumeric.py", line 1377, in ravel
#     return asarray(a).ravel(order)
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/numpy/core/fromnumeric.py", line 1377, in ravel
#     return asarray(a).ravel(order)
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/numpy/core/numeric.py", line 462, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/pradyumna/anaconda/lib/python3.5/site-packages/numpy/core/numeric.py", line 462, in asarray
#     return array(a, dtype, copy=False, order=order)
# KeyboardInterrupt
# KeyboardInterrupt

# %%
# Since it didn't copied well.
iteration_data = [[1,0.003,	0.06,	0.3,	13446.11124],
[2,0.0045,	0.045,	0.2,	13274.65442],
[3,0.00375,	0.0525,	0.15,	13195.83066],
[4,0.00375,	0.04875,	0.125,	13164.16943],
[5,0.0039375,	0.04875,	0.1125,	13159.98718],
[6,0.00384375,	0.04875,	0.10625,	13158.71115],
[7,0.003890625,	0.04921875,	0.103125,	13157.58357],
[8,0.003867188,	0.04921875,	0.1015625,	13157.25843],
[9,0.003867188,	0.049101563,	0.10078125,	13157.07167],
[10,0.003873047,	0.049101563,	0.100390625,	13156.9951],
[11,0.003873047,	0.049101563,	0.100195312,	13156.95771],
[12,0.003871582,	0.049101563,	0.100097656,	13156.93892],
[13,0.003871582,	0.049108887,	0.100048828,	13156.92951],
[14,0.003871582,	0.049105225,	0.100024414,	13156.92484],
[15,0.003871399,	0.049107056,	0.100012207,	13156.9225],
[16,0.003871399,	0.049107056,	0.100006104,	13156.92133],
[17,0.003871399,	0.049106598,	0.100003052,	13156.92075],
[18,0.003871399,	0.049106598,	0.100001526,	13156.92046],
[19,0.003871387,	0.049106712,	0.100000763,	13156.92031],
[20,0.003871387,	0.049106655,	0.100000381,	13156.92024],
[21,0.003871385,	0.049106684,	0.100000191,	13156.9202],
[22,0.003871386,	0.049106684,	0.100000095,	13156.92018],
[23,0.003871385,	0.049106684,	0.100000048,	13156.92017],
[24,0.003871385,	0.049106684,	0.100000024,	13156.92017],
[25,0.003871386,	0.049106684,	0.100000012,	13156.92017],
[26,0.003871386,	0.049106683,	0.100000006,	13156.92016],
[27,0.003871386,	0.049106683,	0.100000003,	13156.92016],
[28,0.003871386,	0.049106683,	0.100000001,	13156.92016],
[29,0.003871386,	0.049106683,	0.100000001,	13156.92016],
[30,0.003871386,	0.049106683,	0.1,	13156.92016],
[32,0.003871386,	0.049106683,	0.1,	13156.92016]]

iteration_data 
iteration_dataf=pd.DataFrame(iteration_data,columns=['Iteration', 'd', 'sigma', 'theta', 'min_NLL'])

iterations_like = iteration_dataf
iterations_like
# Out:
#     Iteration         d     sigma     theta       min_NLL
# 0           1  0.003000  0.060000  0.300000  14426.320831
# 1           2  0.001500  0.060000  0.200000  14249.165216
# 2           3  0.001500  0.052500  0.150000  14100.560179
# 3           4  0.001500  0.052500  0.125000  14087.303413
# 4           5  0.001500  0.050625  0.112500  14077.695636
# 5           6  0.001500  0.051562  0.106250  14073.754716
# 6           7  0.001500  0.051094  0.103125  14071.740680
# 7           8  0.001523  0.051094  0.101562  14070.888601
# 8           9  0.001523  0.051211  0.100781  14070.439959
# 9          10  0.001523  0.051211  0.100391  14070.227052
# 10         11  0.001521  0.051182  0.100195  14070.118659
# 11         12  0.001521  0.051182  0.100098  14070.065485
# 12         13  0.001521  0.051182  0.100049  14070.038874
# 13         14  0.001521  0.051185  0.100024  14070.025566
# 14         15  0.001521  0.051183  0.100012  14070.018914
# 15         16  0.001521  0.051184  0.100006  14070.015589
# 16         17  0.001521  0.051184  0.100003  14070.013926
# 17         18  0.001521  0.051184  0.100002  14070.013095
# 18         19  0.001521  0.051184  0.100001  14070.012679
# 19         20  0.001521  0.051184  0.100000  14070.012472
# 20         21  0.001521  0.051184  0.100000  14070.012368
# 21         22  0.001521  0.051184  0.100000  14070.012316
# 22         23  0.001521  0.051184  0.100000  14070.012290

# %% [raw]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#999; background:#fff;">
# Created with Jupyter, delivered by Fastly, rendered by Rackspace.
# </footer>
