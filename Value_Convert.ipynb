# %%
import numpy as np
import pandas as pd
from pandas.core.frame import DataFrame as DF
import seaborn as sns
sns.set(color_codes=True)
#np.random.seed(sum(map(ord, "distributions")))
from sklearn import linear_model  # packages for the logistic regression function to plot the logistic regression 
from sklearn.linear_model import LogisticRegression # packages for the logistic regression function to plot the logistic regression 
import scipy
from scipy import stats, integrate
from scipy.stats import mode
from scipy.stats.stats import pearsonr # Pearson's correlation
from copy import copy as copy
import operator as operator
import pylab

# %%
data_expData = pd.read_csv('/Users/bdmlab/Documents/GiTs/FF2018/InputData/expdata_FFA_Like_v1.csv')

# %%
data_expData
# Out:
#       parcode  trial    rt  choice  item_left  item_right
# 0           0     40  2009      -1       1.10        0.95
# 1           0     41  3371      -1       2.00        1.70
# 2           0     42  1700       1       1.10        2.30
# 3           0     43  7466       1       1.25        1.40
# 4           0     44  1889       1       2.00        2.30
# 5           0     45  2227       1       1.70        1.85
# 6           0     46  4259      -1       1.85        0.65
# 7           0     47  3505      -1       1.55        0.80
# 8           0     48  2548      -1       1.55        1.10
# 9           0     49  3226       1       1.10        2.00
# 10          0     50  4604      -1       1.85        1.10
# 11          0     51  6333      -1       0.95        2.00
# 12          0     52  5716      -1       0.95        0.80
# 13          0     53  3562      -1       2.00        1.10
# 14          0     54  2447      -1       1.85        1.10
# ...

# %%
for i in (data_expData['parcode'].unique()):
    Choicedata = DataFrameSum1.loc[DataFrameSum1['parcode'] == str(i)]
    # from v3 and on we define DV as  RIGHT - LEFT values of the items
    pX_LV = - pd.to_numeric(Choicedata["item_left"]) 
    pX_RV =   pd.to_numeric(Choicedata["item_right"])
    p_zLV = (pX_LV - np.mean(pX_LV))/np.std(pX_LV)
    p_RLV = (pX_RV - np.mean(pX_RV))/np.std(pX_RV)
        
    z_matrix_aux= np.column_stack((pX_DV,pX_zDV,pX_absDV,pX_zAbsDV,pX_zConf,pX_zChoiceRT))
    
    for  j in range(len(z_matrix_aux)):    
        z_matrix.append(z_matrix_aux[j])
